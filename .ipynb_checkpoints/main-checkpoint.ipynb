# %%
# !pip install -r requirements.txt
from warpdrive import WarpDrive
import requests
import urllib.parse
import uuid
import time
import random
from faker import Faker
from datetime import datetime, timedelta
import json
from json import dumps
 
 
fake = Faker()

# Sample prompt templates and topics
templates = [
    "Explain {topic} like I'm five.",
    "Write a short story about {topic}.",
    "Give an example of {topic} in real life.",
    "What's the opposite of {topic}?",
    "Summarize a debate about {topic}.",
    "How does {topic} affect our daily life?",
    "What are the pros and cons of {topic}?",
    "What is the future of {topic}?",
    "Why is {topic} important in school?",
    "Describe a funny situation involving {topic}.",
    "What are common misconceptions about {topic}?",
    "Create a poem about {topic}.",
    "Tell me a fact about {topic}.",
    "Write a joke about {topic}.",
    "Describe {topic} using a sports analogy."
]

# More diverse topics
topics = [
    "blockchain", "gravity", "photosynthesis", "climate change", "AI", "inflation",
    "quantum physics", "machine learning", "nutrition", "vaccination",
    "data privacy", "recycling", "mental health", "electric vehicles",
    "renewable energy", "genetics", "robotics", "economics", "black holes", "meditation"
]

# More fake responses
responses = [
    "It's a process plants use to make food.",
    "A chain of computers that work together.",
    "It makes things fall to the ground.",
    "It affects how much things cost over time.",
    "A hot topic with many opinions!",
    "People often confuse it with something else.",
    "It has changed the world in the last decade.",
    "Used in both science fiction and real tech.",
    "Very relevant in today’s discussions.",
    "Both kids and adults are impacted by it."
]
# Generate a list of Purview-style logs
def generate_logs(n=10):
    logs = []
    now = datetime.utcnow()
    for _ in range(n):
        prompt = random.choice(templates).format(topic=random.choice(topics))
        response = random.choice(responses)
        timestamp = (now - timedelta(seconds=random.randint(0, 10000))).isoformat() + "Z"
        log_entry = {
            "prompt": prompt,
            "response": response,
            "timestamp": timestamp
        }
        logs.append(log_entry)
    return logs

# Create and export logs
json_logs = generate_logs(10)
print(json.dumps(json_logs, indent=2))



wd = WarpDrive()


username = wd.get_args("username")
password = wd.get_args("password")
pipeline_id = wd.get_args("pipeline_id")
project_id = wd.get_args("project_id")
model_id = wd.get_args("model_id")
model_family = wd.get_args("model_family")

url = "https://nimbus-uno-qa.nginx.solyticspartners.com/genai/llm/rpd-metrics"
base_login_url = "https://nimbus-uno-qa.nginx.solyticspartners.com/auth/auth/login/"
token_url = "https://nimbus-uno-qa.nginx.solyticspartners.com/auth/auth/token/"
 
def generate_device_id():
    return f"3214123195-{uuid.uuid4()}-{int(time.time() * 1000)}"
 
Org = "qa"
# your code here
login_headers = {
            "x-tenant-id": Org,
            "x-device-id": generate_device_id()
        }
login_payload = {
            'email': (None, username),
            'password': (None, password),
            'product_domain': (None, "https://nimbus-uno-qa.solyticspartners.com/")
        }
 
res = requests.post(url=base_login_url, files=login_payload, headers=login_headers)
assert res.status_code == 200, f"Invalid status code for login: {res.status_code}, {res.text}"
 
try:
    response_json = res.json()
    #print("Response JSON:", response_json)
    print(f"Login Successful.")
except ValueError:
    print("Response is not valid JSON:")
    print(res.text)
 
# Parse the redirect URL
parsed_url = urllib.parse.urlparse(response_json["redirect_url"])
query_params = urllib.parse.parse_qs(parsed_url.query)
 
# Extract the 'code' parameter
code = query_params.get("code", [None])[0]
session_id = response_json.get("session_id")
#print(session_id)
# print("Extracted Code:", code)
 
token_payload = {"code": code}
token_res = requests.post(url=token_url, headers=login_headers, data=token_payload)
# print(self.token_payload)
assert token_res.status_code == 200, f"Invalid status code for login: {token_res.status_code}, {token_res.text}"
 
try:
    print("Token API Successful.")
    print("Acquiring access token.")
    token_data = token_res.json()  # parse JSON from response
    token = 'Bearer ' + token_data["access_token"]
    print(token)
except Exception as exp:
    print(f"Failed to acquire token \n{exp}\n", token_res.text)
def convert_json_to_prompt_data(json_data, latency=None):
    """
    Convert a list of dicts with 'prompt', 'response', and 'timestamp' keys
    to prompt_data format with optional latency added.
    """
    print(json_data)
    return [
        {
            "prompt": entry.get("prompt", ""),
            "response": entry.get("response", ""),
            "timestamp": entry.get("timestamp", ""),
            "latency": latency
        }
        for entry in json_data
    ]

prompt_data = convert_json_to_prompt_data(json_logs, latency=0.25)
print(prompt_data)

headers = {
        "Authorization": token,
        "Org": Org,
        "Content-Type": "application/json"
    }


input_cost = random_int = random.randint(10, 20)
output_cost = random_int = random.randint(10, 20)
payload = {
        "project_id": project_id,
        "pipeline_id": pipeline_id,
        "model_family": model_family,
        "selected_models": [model_id],
        "metrics": ["response_readability","response_coleman_liau_index","response_polarity","lexical_diversity"],
        "prompt_data": prompt_data,
        "model_check": True
    }


response = requests.post(url = url, headers=headers, json=payload)

if response.status_code == 200:
    print(response.json())
else:
    response.raise_for_status()
# Out:
# Collecting faker (from -r requirements.txt (line 1))
#   Downloading faker-37.4.0-py3-none-any.whl.metadata (15 kB)
# Collecting promptgen (from -r requirements.txt (line 2))
#   Downloading promptgen-0.0.2-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (2.28.2)
# Collecting datetime (from -r requirements.txt (line 4))
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Collecting tzdata (from faker->-r requirements.txt (line 1))
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting ply>=3.11 (from promptgen->-r requirements.txt (line 2))
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 3)) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 3)) (2025.6.15)
# Collecting zope.interface (from datetime->-r requirements.txt (line 4))
#   Downloading zope.interface-7.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/site-packages (from datetime->-r requirements.txt (line 4)) (2023.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/site-packages (from zope.interface->datetime->-r requirements.txt (line 4)) (80.9.0)
# Downloading faker-37.4.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 9.1 MB/s eta 0:00:00a 0:00:01
# Downloading promptgen-0.0.2-py3-none-any.whl (35 kB)
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading zope.interface-7.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (254 kB)
# Installing collected packages: ply, zope.interface, tzdata, promptgen, faker, datetime
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [datetime]5/6 [datetime]rface]
# Successfully installed datetime-5.5 faker-37.4.0 ply-3.11 promptgen-0.0.2 tzdata-2025.2 zope.interface-7.2
# /usr/local/lib/python3.10/site-packages/mlflow/utils/requirements_utils.py:20: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources  # noqa: TID251
# [
#   {
#     "prompt": "How does recycling affect our daily life?",
#     "response": "It has changed the world in the last decade.",
#     "timestamp": "2025-06-23T08:54:15.499211Z"
#   },
#   {
#     "prompt": "How does economics affect our daily life?",
#     "response": "Used in both science fiction and real tech.",
#     "timestamp": "2025-06-23T10:32:20.499211Z"
#   },
#   {
#     "prompt": "Explain recycling like I'm five.",
#     "response": "It makes things fall to the ground.",
#     "timestamp": "2025-06-23T10:35:33.499211Z"
#   },
#   {
#     "prompt": "Create a poem about mental health.",
#     "response": "A hot topic with many opinions!",
#     "timestamp": "2025-06-23T08:01:51.499211Z"
#   },
#   {
#     "prompt": "What are common misconceptions about climate change?",
#     "response": "It's a process plants use to make food.",
#     "timestamp": "2025-06-23T09:50:59.499211Z"
#   },
#   {
#     "prompt": "Write a short story about genetics.",
#     "response": "Very relevant in today\u2019s discussions.",
#     "timestamp": "2025-06-23T10:16:21.499211Z"
#   },
#   {
#     "prompt": "Write a short story about nutrition.",
#     "response": "It makes things fall to the ground.",
#     "timestamp": "2025-06-23T09:26:01.499211Z"
#   },
#   {
#     "prompt": "Describe a funny situation involving genetics.",
#     "response": "A hot topic with many opinions!",
#     "timestamp": "2025-06-23T08:40:26.499211Z"
#   },
#   {
#     "prompt": "Summarize a debate about AI.",
#     "response": "Very relevant in today\u2019s discussions.",
#     "timestamp": "2025-06-23T09:00:30.499211Z"
#   },
#   {
#     "prompt": "Write a short story about inflation.",
#     "response": "A hot topic with many opinions!",
#     "timestamp": "2025-06-23T09:24:36.499211Z"
#   }
# ]
# Login Successful.
# Token API Successful.
# Acquiring access token.
# Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..qKulO2aWiLtcFhdmNg55Rao8xRrluRHZ789WfFsG2FA8u-oT3N-X7WZCffD_MtUFJC7h0RPwxVlSUfkUp_PEsZbQRr5MRzYbUS-nyPCrTnlj9ZN5b-_FrqlRoJ2e483I-QfMdibjsl94XBJ6N5BBLyBCcgUNg3uDWfQmz2Y2SkX6rfd5jX6ju4MRpjcJwhadGn-yoAj52RUQ4wviYKnLc5TkgImqqfPtkdgABQPgMKqW31wcSPN4Cd_fodQ3SacsJRXTQzrIODd0ldI6HLsPSuYE7i6XoqJQ0uXE8Jd6d65RtsKK1yEgrIJjKEDUSKLCg4UC01FZPH7mZo1UbJGTew
# [{'prompt': 'How does recycling affect our daily life?', 'response': 'It has changed the world in the last decade.', 'timestamp': '2025-06-23T08:54:15.499211Z'}, {'prompt': 'How does economics affect our daily life?', 'response': 'Used in both science fiction and real tech.', 'timestamp': '2025-06-23T10:32:20.499211Z'}, {'prompt': "Explain recycling like I'm five.", 'response': 'It makes things fall to the ground.', 'timestamp': '2025-06-23T10:35:33.499211Z'}, {'prompt': 'Create a poem about mental health.', 'response': 'A hot topic with many opinions!', 'timestamp': '2025-06-23T08:01:51.499211Z'}, {'prompt': 'What are common misconceptions about climate change?', 'response': "It's a process plants use to make food.", 'timestamp': '2025-06-23T09:50:59.499211Z'}, {'prompt': 'Write a short story about genetics.', 'response': 'Very relevant in today’s discussions.', 'timestamp': '2025-06-23T10:16:21.499211Z'}, {'prompt': 'Write a short story about nutrition.', 'response': 'It makes things fall to the ground.', 'timestamp': '2025-06-23T09:26:01.499211Z'}, {'prompt': 'Describe a funny situation involving genetics.', 'response': 'A hot topic with many opinions!', 'timestamp': '2025-06-23T08:40:26.499211Z'}, {'prompt': 'Summarize a debate about AI.', 'response': 'Very relevant in today’s discussions.', 'timestamp': '2025-06-23T09:00:30.499211Z'}, {'prompt': 'Write a short story about inflation.', 'response': 'A hot topic with many opinions!', 'timestamp': '2025-06-23T09:24:36.499211Z'}]
# [{'prompt': 'How does recycling affect our daily life?', 'response': 'It has changed the world in the last decade.', 'timestamp': '2025-06-23T08:54:15.499211Z', 'latency': 0.25}, {'prompt': 'How does economics affect our daily life?', 'response': 'Used in both science fiction and real tech.', 'timestamp': '2025-06-23T10:32:20.499211Z', 'latency': 0.25}, {'prompt': "Explain recycling like I'm five.", 'response': 'It makes things fall to the ground.', 'timestamp': '2025-06-23T10:35:33.499211Z', 'latency': 0.25}, {'prompt': 'Create a poem about mental health.', 'response': 'A hot topic with many opinions!', 'timestamp': '2025-06-23T08:01:51.499211Z', 'latency': 0.25}, {'prompt': 'What are common misconceptions about climate change?', 'response': "It's a process plants use to make food.", 'timestamp': '2025-06-23T09:50:59.499211Z', 'latency': 0.25}, {'prompt': 'Write a short story about genetics.', 'response': 'Very relevant in today’s discussions.', 'timestamp': '2025-06-23T10:16:21.499211Z', 'latency': 0.25}, {'prompt': 'Write a short story about nutrition.', 'response': 'It makes things fall to the ground.', 'timestamp': '2025-06-23T09:26:01.499211Z', 'latency': 0.25}, {'prompt': 'Describe a funny situation involving genetics.', 'response': 'A hot topic with many opinions!', 'timestamp': '2025-06-23T08:40:26.499211Z', 'latency': 0.25}, {'prompt': 'Summarize a debate about AI.', 'response': 'Very relevant in today’s discussions.', 'timestamp': '2025-06-23T09:00:30.499211Z', 'latency': 0.25}, {'prompt': 'Write a short story about inflation.', 'response': 'A hot topic with many opinions!', 'timestamp': '2025-06-23T09:24:36.499211Z', 'latency': 0.25}]
# {'task_id': '3a9fdfe8-707e-49e9-a9b0-d9e902d40016'}
