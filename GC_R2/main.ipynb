# %%
# !pip install -r requirements.txt
from warpdrive import WarpDrive


wd = WarpDrive()

png = wd.get_args("png")
txt = wd.get_args("txt")
df = wd.get_args("df")
col = wd.get_args("col")
str = wd.get_args("str")
int = wd.get_args("int")
flt = wd.get_args("flt")
bol = wd.get_args("bol")
# your code here
wd.save_png(png)
wd.create_df(df)
wd.save_table(col)
print(txt)
print(str)
print(int)
print(flt)
print(bol)
